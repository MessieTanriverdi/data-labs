# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?campaigns=fr_ss19_eoss_fs_wave_3_2019_26&categories=enfant&limit=84&offset=84&sort=popularity'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
# Your code

response = requests.get(url, headers={"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36"})
results = response.json()
results

flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1.head()
# Out:
#    brand_name                                    family_articles  \
# 0    Converse  [{'sku': 'CO413A01B-A11', 'url_key': 'converse...
# 1      Friboo  [{'sku': 'F5723G04P-J11', 'url_key': 'friboo-t...
# 2       Guess  [{'sku': 'GU124L01W-K11', 'url_key': 'guess-ja...
# 3  Quiksilver  [{'sku': 'QU124K03N-C11', 'url_key': 'quiksilv...
# 4    DC Shoes  [{'sku': 'DC124L01C-Q11', 'url_key': 'dc-shoes...
#
#                                                flags  is_premium  \
# 0  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 1  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 2  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 3  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 4  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
#
#                                                media  \
# 0  [{'path': 'CO/41/3A/01/BA/11/CO413A01B-A11@12....
# 1  [{'path': 'F5/72/3G/04/PJ/11/F5723G04P-J11@2.j...
# 2  [{'path': 'GU/12/4L/01/WK/11/GU124L01W-K11@5.j...
# 3  [{'path': 'QU/12/4K/03/NC/11/QU124K03N-C11@7.j...
# 4  [{'path': 'DC/12/4L/01/CQ/11/DC124L01C-Q11@7.j...
#
#                                                 name  \
# 0  CHUCK TAYLOR FIRST STAR - Chaussons pour bébé ...
# 1                      T-shirt imprimé - powder pink
# 2      JACKET - Veste en jean - dark light blue wash
# 3  POWER SLASH ZIP YOUTH - veste en sweat zippée ...
# 4    DAZZLE DAGUP BOY - Veste de survêtement - black
#
#    price.has_different_original_prices  price.has_different_prices  \
# 0                                False                       False
# 1                                False                        True
# 2                                False                       False
# 3                                False                        True
# 4                                False                        True
#
#    price.has_different_promotional_prices  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                    True
# 4                                    True
#
#    price.has_discount_on_selected_sizes_only price.original price.promotional  \
# 0                                      False        29,95 €           19,47 €
# 1                                      False        14,95 €            6,00 €
# 2                                      False        99,95 €           29,95 €
# 3                                      False        49,99 €           20,00 €
# 4                                      False        59,95 €           17,95 €
#
#   product_group                                         sizes            sku  \
# 0          shoe                              [17, 18, 19, 20]  CO413A01B-A11
# 1      clothing  [110/116, 122/128, 134/140, 146/152, 98/104]  F5723G04P-J11
# 2      clothing             [7a, 8a, 10a, 12a, 14a, 16a, 18a]  GU124L01W-K11
# 3      clothing                           [8a, 12a, 14a, 16a]  QU124K03N-C11
# 4      clothing              [16a, 10a/11a, 12a/13a, 14a/15a]  DC124L01C-Q11
#
#                                              url_key
# 0  converse-first-star-chaussons-pour-bebe-co413a...
# 1   friboo-t-shirt-imprime-powder-pink-f5723g04p-j11
# 2  guess-jacket-veste-en-jean-dark-light-blue-was...
# 3  quiksilver-power-slash-zip-youth-veste-en-swea...
# 4  dc-shoes-dazzle-dagup-boy-veste-de-survetement...

# %% [markdown]
# ### Collect all the objects from selected filters.
#
# Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?campaigns=fr_ss19_eoss_fs_wave_3_2019_26&categories=enfant&limit=84&offset=84&sort=popularity'
    response = requests.get(url, headers={"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36"})
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df.head()
# Out:
#                brand_name                                    family_articles  \
# sku
# CO413A01B-A11    Converse  [{'sku': 'CO413A01B-A11', 'url_key': 'converse...
# F5723G04P-J11      Friboo  [{'sku': 'F5723G04P-J11', 'url_key': 'friboo-t...
# GU124L01W-K11       Guess  [{'sku': 'GU124L01W-K11', 'url_key': 'guess-ja...
# QU124K03N-C11  Quiksilver  [{'sku': 'QU124K03N-C11', 'url_key': 'quiksilv...
# DC124L01C-Q11    DC Shoes  [{'sku': 'DC124L01C-Q11', 'url_key': 'dc-shoes...
#
#                                                            flags  is_premium  \
# sku
# CO413A01B-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# F5723G04P-J11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# GU124L01W-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# QU124K03N-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# DC124L01C-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
#
#                                                            media  \
# sku
# CO413A01B-A11  [{'path': 'CO/41/3A/01/BA/11/CO413A01B-A11@12....
# F5723G04P-J11  [{'path': 'F5/72/3G/04/PJ/11/F5723G04P-J11@2.j...
# GU124L01W-K11  [{'path': 'GU/12/4L/01/WK/11/GU124L01W-K11@5.j...
# QU124K03N-C11  [{'path': 'QU/12/4K/03/NC/11/QU124K03N-C11@7.j...
# DC124L01C-Q11  [{'path': 'DC/12/4L/01/CQ/11/DC124L01C-Q11@7.j...
#
#                                                             name  \
# sku
# CO413A01B-A11  CHUCK TAYLOR FIRST STAR - Chaussons pour bébé ...
# F5723G04P-J11                      T-shirt imprimé - powder pink
# GU124L01W-K11      JACKET - Veste en jean - dark light blue wash
# QU124K03N-C11  POWER SLASH ZIP YOUTH - veste en sweat zippée ...
# DC124L01C-Q11    DAZZLE DAGUP BOY - Veste de survêtement - black
#
#                price.has_different_original_prices  \
# sku
# CO413A01B-A11                                False
# F5723G04P-J11                                False
# GU124L01W-K11                                False
# QU124K03N-C11                                False
# DC124L01C-Q11                                False
#
#                price.has_different_prices  \
# sku
# CO413A01B-A11                       False
# F5723G04P-J11                        True
# GU124L01W-K11                       False
# QU124K03N-C11                        True
# DC124L01C-Q11                        True
#
#                price.has_different_promotional_prices  \
# sku
# CO413A01B-A11                                   False
# F5723G04P-J11                                    True
# GU124L01W-K11                                   False
# QU124K03N-C11                                    True
# DC124L01C-Q11                                    True
#
#                price.has_discount_on_selected_sizes_only price.original  \
# sku
# CO413A01B-A11                                      False        29,95 €
# F5723G04P-J11                                      False        14,95 €
# GU124L01W-K11                                      False        99,95 €
# QU124K03N-C11                                      False        49,99 €
# DC124L01C-Q11                                      False        59,95 €
#
#               price.promotional product_group  \
# sku
# CO413A01B-A11           19,47 €          shoe
# F5723G04P-J11            6,00 €      clothing
# GU124L01W-K11           29,95 €      clothing
# QU124K03N-C11           20,00 €      clothing
# DC124L01C-Q11           17,95 €      clothing
#
#                                                       sizes  \
# sku
# CO413A01B-A11                              [17, 18, 19, 20]
# F5723G04P-J11  [110/116, 122/128, 134/140, 146/152, 98/104]
# GU124L01W-K11             [7a, 8a, 10a, 12a, 14a, 16a, 18a]
# QU124K03N-C11                           [8a, 12a, 14a, 16a]
# DC124L01C-Q11              [16a, 10a/11a, 12a/13a, 14a/15a]
#
#                                                          url_key
# sku
# CO413A01B-A11  converse-first-star-chaussons-pour-bebe-co413a...
# F5723G04P-J11   friboo-t-shirt-imprime-powder-pink-f5723g04p-j11
# GU124L01W-K11  guess-jacket-veste-en-jean-dark-light-blue-was...
# QU124K03N-C11  quiksilver-power-slash-zip-youth-veste-en-swea...
# DC124L01C-Q11  dc-shoes-dazzle-dagup-boy-veste-de-survetement...

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# df.brand_name.value_counts()
# Out:
# 'Benetton'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
# Our data is still text. Convert prices into numbers:

df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)

df1 = df.copy()

# %%
total_disc = df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Bardot Junior'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)
